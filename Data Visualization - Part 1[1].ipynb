# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib is a plotting library for Python Programming Language and its numerical python extension (NUMPY)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.artist #Class in matplotlib which paints

# %%
#Create line chart --> plot(x,y)
x=range(1,11) #x axis
y=[1,5,8,9,2,0,3,10,4,7] #y axis
plt.plot(x,y) # range is x axis ie pts(1,1),(2,5),(3,8)..last x=10
#Can Change the scale
plt.xlim(0,20) #Xscale 0,20 --> Limit Range
plt.ylim(0,20) #Yscale 0,20 --> Limit Range
plt.show()

# %%
#Create Multiple line chart --> plot(x,y)
x=range(1,11) #x axis
y=[1,5,8,9,2,0,3,10,4,7] #y axis
y1=[2,4,6,8,1,3,5,7,9,2]
plt.plot(x,y) # range is x axis ie pts(1,1),(2,5),(3,8)..last x=10
plt.plot(x,y1)
#Can Change the scale
#plt.xlim(0,20) #Xscale 0,20 --> Limit Range
#plt.ylim(0,20) #Yscale 0,20 --> Limit Range
plt.savefig('Multiple Line Chart.png')
plt.show()

# %% [markdown]
# #Edit Axes
# Call matplotlib.pyplot.xlim(limit_range) to restrict the range to limit_range for the x-axis of the plot. Call matplotlib.pyplot.ylim(limit_range) to restrict the range to limit_range for the y-axis of the plot.

# %%
plt.plot(range(5))
plt.show()

# %%
print(range(5))
# Out:
# range(0, 5)

# %%
plt.plot(range(5))
plt.xlim(-5, 5)
plt.ylim(-5, 5)
# Out:
# (-5.0, 5.0)

# %% [markdown]
# The axis limits to be set. This can also be achieved using
# ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))

# %%
# Create Pie Chart, plots the % of each value
values=[5,8,9,10,4,7]
#color
col=['b','g','c','m','y','r']
#label
lab=['A','B','C','D','E','F']
# Cut Slice (Explode)
exp=[0,0,0,0,0,0.9]

plt.pie(values,colors=col,labels=lab,explode=exp,
        autopct='%.f%%',counterclock=False) #autopct --> string formatting for display of percentage
plt.show()

# %%
#Pie Chart
country=['Norway','Germany','Canada','United States','Netherlands']
medal=[14,15,11,9,8]
col=['b','g','m','c','y']
exp=[0,0.2,0,0,0]
plt.pie(medal,colors=col,labels=country,explode=exp,autopct='%1.2f%%',shadow=True)
plt.title('Medal Tally',fontsize=15)
plt.show()

# %%
#Create Bar Chart
x=range(1,7)
y=[5,8,9,10,4,7]
col=['b','g','c','m','y','r']
plt.bar(x,y,color=col)
plt.savefig('Bar Chart.png') #Save fig before plt.show()
plt.show()

# %%
city=['Delhi','Beijing','Washington','Tokyo','Moscow']
happiness_index=[60,40,70,65,85]
col=['b','g','c','m','y']
plt.xlabel('City')
plt.ylabel('Happiness Index')
plt.title('Happiness Graph',fontsize=20)
plt.grid()
plt.bar(city,happiness_index,color=col)
# To print the qty of each bar on top of it 
for x,y in zip(city,happiness_index):
    plt.text(x,y,y) #(x,y) --> Coordinate system , y--> str text (y)
plt.show()

# %%
# Create Histogram, Plots the frequency of the values
values = [82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,110]
plt.hist(values,6,histtype='bar',edgecolor='black',color='g') # 5 is no of bins (can be 5,6,7)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Create Histogram
heights=[189 ,170, 189, 163, 183, 171, 185, 172, 173, 183, 173, 173, 175, 178, 183, 193, 178, 173,  174, 183, 183, 168, 170, 200, 182, 180, 183, 178, 182, 188, 175, 179, 183, 193, 182, 183,  177, 185, 188, 188, 182, 185]
plt.hist(heights,8,histtype='bar',edgecolor='blue')
plt.show()

# %%
#Grouped Bar Chart
x = np.arange(5) 
y1 = [34, 56, 12, 89, 67] 
y2 = [12, 56, 78, 45, 90] 
width = 0.10
  
# plot data in grouped manner of bar type 
plt.bar(x-0.2, y1, width) 
plt.bar(x+0.2, y2, width)
# Out:
# <BarContainer object of 5 artists>

# %%
# Create Single Box Plot
value1 = [82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
#box_data=[value1]
lab=['Course1']

#vert=0 or 1 [0 = horizontal], patch_artist= True / False [If False produces boxes with the Line2D artist],
#show fliers = show the outliers

plt.boxplot(value1,vert=0,patch_artist=True,labels=lab,showfliers=1)
plt.show()
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1425/2152890646.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(value1,vert=0,patch_artist=True,labels=lab,showfliers=1)

# %%
# Create Multiple Box Plot
value1 = [82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
value2=[62,5,91,25,36,32,96,95,3,90,95,32,27,55,100,15,71,11,37,21]
value3=[23,89,12,78,72,89,25,69,68,86,19,49,15,16,16,75,65,31,25,52]
value4=[59,73,70,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

box_data=[value1,value2,value3,value4]
lab=['Course1','Course2','Course3','Course4']

#vert=0 or 1 [0 = horizontal], patch_artist= True / False [If False produces boxes with the Line2D artist],
#show fliers = show the outliers
#Pass the list of Values to plt.boxplot
plt.boxplot(box_data,vert=0,patch_artist=True,labels=lab,showfliers=1)
plt.show()
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1425/3500125709.py:13: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(box_data,vert=0,patch_artist=True,labels=lab,showfliers=1)

# %%
# Create Scatter plot between two numerical variables
weight1=[63.3,57,64.3,63,71,61.8,62.9,65.6,64.8,63.1,68.3,69.7,65.4,66.3,60.7]
height1=[156.3,100.7,114.8,156.3,237.1,123.9,151.8,164.7,105.4,136.1,175.2,137.4,164.2,151,124.3]
plt.xlabel('Weight')
plt.ylabel('Height')
#c = color, marker = 'shape'
plt.scatter(weight1,height1,color='green',marker='*')
plt.show()

# %%
import random
x=random.sample(range(1,50),10)
y=random.sample(range(10,60),10)
plt.xlabel('Random x values')
plt.ylabel('Random y values')
plt.scatter(x,y,c='b',marker='*')
plt.show()

# %%
lang=['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
col=['b','g','m','c','y','r']
plt.bar(lang,popularity,color=col)
for x,y in zip(lang,popularity):
    plt.text(x,y,y)
plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn updates Matplotlib's (run command (rc) parameters) to improve aesthetics
# Seaborn sits on the top of matplot lib code & provides better functionality ie better syntax, better defaults
# Seaborn runs with matplotlib
# Seaborn also integrates with pandas -- It allows seaborn group, aggregate and plot pandas dataframes

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 10, 4, 5]
y = [2, 4, 6, 8, 10]

# Create line plot using Seaborn
sns.lineplot(x=x, y=y)

# Set plot labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Chart')

# Display the plot
plt.show()

# %%
#Seaborne Univariate kernel density Plot

# %%
#from matplotlib import pyplot as plt
import seaborn as sns

# %%
import seaborn as sns

# Get the list of available datasets
datasets = sns.get_dataset_names()

# Print the dataset names
for dataset in datasets:
    print(dataset)
# Out:
# anagrams
# anscombe
# attention
# brain_networks
# car_crashes
# diamonds
# dots
# dowjones
# exercise
# flights
# fmri
# geyser
# glue
# healthexp
# iris
# mpg
# penguins
# planets
# seaice
# taxis
# tips
# titanic

# %%
cars =sns.load_dataset('mpg').dropna()
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [392 rows x 9 columns]

# %%
#iris =sns.load_dataset('iris').dropna()
#iris

# %%
sns.relplot(x="model_year", y='mpg',col='origin',hue='cylinders',data=cars) #Multidimension Representation
#Different col = Column for origin

# %%
cars.shape
# Out:
# (392, 9)

# %%
#cars.head

# %% [markdown]
# A density plot is a representation of the distribution of a numeric variable. It uses a kernel density estimate to show the probability density function of the variable (see more). It is a smoothed version of the histogram and is used in the same concept.

# %% [markdown]
# Density Plot is a type of data visualization tool. It is a variation of the histogram that uses 'kernel smoothing' while plotting the values. It is a continuous and smooth version of a histogram inferred from a data. ... Density plots can be made using pandas, seaborn, etc.

# %% [markdown]
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %% [markdown]
# KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable.

# %%
sns.kdeplot(cars.horsepower)

#Most Cars have the Horse power of 80, some cars have around 150
# Out:
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, shade =True)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1425/1742834672.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(cars.horsepower, shade =True)
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
import seaborn as sns

# Create KDE plot with custom shade color
sns.kdeplot(cars.horsepower, shade=True, color='red')

# Set plot labels and title
plt.xlabel('Horsepower')
plt.ylabel('Density')
plt.title('KDE Plot')

# Display the plot
plt.show()
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1425/3748125805.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(cars.horsepower, shade=True, color='red')

# %%
sns.kdeplot(cars.horsepower,bw=10)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1425/1169620454.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=10`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(cars.horsepower,bw=10)
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower,bw=100) 
#As we increase the bin width the curve smoothens and tends to be normal #Looses out on peaks
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1425/959150384.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=100`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.14.0.
#
#   sns.kdeplot(cars.horsepower,bw=100)
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
#Cumulative Density Plot (cdf)
sns.kdeplot(cars.horsepower,cumulative=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[41], line 2
#       1 #Cumulative Density Plot (cdf)
# ----> 2 sns.kdeplot(cars.horsepower,cumulative=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/distributions.py:1701, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1697 if p.univariate:
#    1699     plot_kws = kwargs.copy()
# -> 1701     p.plot_univariate_density(
#    1702         multiple=multiple,
#    1703         common_norm=common_norm,
#    1704         common_grid=common_grid,
#    1705         fill=fill,
#    1706         color=color,
#    1707         legend=legend,
#    1708         warn_singular=warn_singular,
#    1709         estimate_kws=estimate_kws,
#    1710         **plot_kws,
#    1711     )
#    1713 else:
#    1715     p.plot_bivariate_density(
#    1716         common_norm=common_norm,
#    1717         fill=fill,
#    (...)
#    1727         **kwargs,
#    1728     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/distributions.py:930, in _DistributionPlotter.plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, color, legend, estimate_kws, **plot_kws)
#     927     common_grid = True
#     929 # Do the computation
# --> 930 densities = self._compute_univariate_density(
#     931     self.data_variable,
#     932     common_norm,
#     933     common_grid,
#     934     estimate_kws,
#     935     warn_singular,
#     936 )
#     938 # Adjust densities based on the `multiple` rule
#     939 densities, baselines = self._resolve_multiple(densities, multiple)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/distributions.py:308, in _DistributionPlotter._compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, warn_singular)
#     298 def _compute_univariate_density(
#     299     self,
#     300     data_variable,
#    (...)
#     306
#     307     # Initialize the estimator object
# --> 308     estimator = KDE(**estimate_kws)
#     310     if set(self.variables) - {"x", "y"}:
#     311         if common_grid:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_statistics.py:86, in KDE.__init__(self, bw_method, bw_adjust, gridsize, cut, clip, cumulative)
#      83 self.cumulative = cumulative
#      85 if cumulative and _no_scipy:
# ---> 86     raise RuntimeError("Cumulative KDE evaluation requires scipy")
#      88 self.support = None
#
# RuntimeError: Cumulative KDE evaluation requires scipy

# %%
#Distribution Plot --> Combines the functionalty of Rug Plot, Histogram & KDE Plot in one

# %%
sns.distplot(cars.weight)
#default distplot includes histogram and kdeplot
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/3541306736.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight)
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#Look at histogram only, Seaborn does not have seperate histogram function it can be created using distplot as below
sns.distplot(cars.weight,kde=False)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/602134414.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,kde=False)
# <Axes: xlabel='weight'>

# %%
#Look at kde plot only
sns.distplot(cars.weight,hist=False)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/4237729949.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,hist=False)
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#Look at KDE & Rug Plot
sns.distplot(cars.weight,hist=False,rug=True)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/3113168390.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,hist=False,rug=True)
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#Bins --> Equally Spaced Bins
sns.distplot(cars.weight,bins=5)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/1608923322.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,bins=5)
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#No of bins are less
sns.distplot(cars.weight,bins=20)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/2158452731.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,bins=20)
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#Size of bins is different --> Pass list of the bins size
sns.distplot(cars.weight,bins=[1500,2000,3500,4500,5200])
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/2547229756.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,bins=[1500,2000,3500,4500,5200])
# <Axes: xlabel='weight', ylabel='Density'>

# %%
#Fit --> Fitting Distribution to Data from scipy library

# %%
from scipy.stats import norm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 from scipy.stats import norm
#
# ModuleNotFoundError: No module named 'scipy'

# %%
sns.distplot(cars.weight,fit=norm) #KDE Plot, Histogram & Normal--> Data has a skew
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.distplot(cars.weight,fit=norm) #KDE Plot, Histogram & Normal--> Data has a skew
#
# NameError: name 'norm' is not defined

# %%
sns.distplot(cars.weight,fit=norm,kde=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sns.distplot(cars.weight,fit=norm,kde=False)
#
# NameError: name 'norm' is not defined

# %%
#Frequency Histogram

sns.distplot(cars.weight,kde=False)
# Out:
# /var/folders/fw/pcsq41mj2kg8k4cvhtxt3znr0000gn/T/ipykernel_1200/230718379.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,kde=False)
# <Axes: xlabel='weight'>

# %%
#Swarm Plot/ Bees Plot

# %%
sns.swarmplot(cars.horsepower) #one dot for each data point in the dataset
# Out:
# <Axes: ylabel='horsepower'>

# %%
sns.swarmplot(x='origin',y='horsepower',data=cars) #one dot for each data point in the dataset
# Out:
# <Axes: xlabel='origin', ylabel='horsepower'>
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='origin',y='horsepower',hue='cylinders',data=cars) #one dot for each data point in the dataset
# Out:
# <Axes: xlabel='origin', ylabel='horsepower'>
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#strip plot --> Jitter is the feature of strip plot --> Categorical Scatter Plots (Swarm plot and strip plot convey similar info)
#Here color intensity indicates density

# %%
sns.stripplot(cars.weight)
# Out:
# <Axes: ylabel='weight'>

# %%
sns.stripplot(cars.weight,cars.origin)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 sns.stripplot(cars.weight,cars.origin)
#
# TypeError: stripplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.stripplot(cars.weight,cars.origin)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.stripplot(cars.weight,cars.origin)
#
# TypeError: stripplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.stripplot(x='weight',y='origin', hue='cylinders',data=cars)
# Out:
# <Axes: xlabel='weight', ylabel='origin'>

# %%
sns.scatterplot(cars.mpg,cars.weight)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 sns.scatterplot(cars.mpg,cars.weight)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.pairplot(cars)

# %%
sns.heatmap(cars.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 sns.heatmap(cars.corr())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'usa'

# %%
sns.boxplot(cars.weight)
# Out:
# <Axes: ylabel='weight'>
