# %% [markdown]
# <a href="https://colab.research.google.com/github/hrcn81/decipher/blob/main/Practice/Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/hrcn81/commonplace/main/Datasets/googleplaystore.csv')

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (9360, 13)

# %%
9360/10841*100
# Out:
# 86.33889862558804

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# # Numeric

# %%
df1 = data.copy().dropna()

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# df1.iloc[:,2:3]
# df1.loc[:,'Rating']
# df1.iloc[:,df1.columns == 'Rating']
# df1.loc[:, ['Rating', 'Reviews', 'Size']]

# df1.iloc[:,df1.columns in df1['Rating','Reviews', 'Size']]      # ERROR

# %%
df1['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10834    4.0
# 10836    4.5
# 10837    5.0
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 9360, dtype: float64

# %%
round(int(sum(df1['Rating']))/9360,2)
# Out:
# 4.19

# %%
# str(int(sum(df1['Rating']))/9360)[:4]

# %%
sum(df1['Rating'])/len(df1['Rating'])
# Out:
# 4.191837606837612

# %%
df1['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10834    4.0
# 10836    4.5
# 10837    5.0
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 9360, dtype: float64

# %%
s = 0
for i in df1['Rating']:
  if i in [5.0]:
    s += 1
print(s)
# Out:
# 274

# %%
ch = 0
for i in df1['Rating']:
  if (i >= 4 and i <= 5):
    ch +=1
print(ch)
# Out:
# 7363

# %%
df1['Reviews'].sum()
# Out:
# '...'

# %%
s = 0
for i in df['Reviews']:
  s += int(i)

print(s)
print(len(df1['Reviews']))
print(round(s/len(df1['Reviews']),2))
# Out:
# 4814565961
# 9360
# 514376.71

# %% [markdown]
# # Cartegorical

# %%
data.shape
# Out:
# (10841, 13)

# %%
df2 = data.copy().dropna()

# %%
df2.shape
# Out:
# (9360, 13)

# %%
df2.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df2.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
w = 0
for i in df2.columns:
  w += 1
  print(w,i)
# Out:
# 1 App
# 2 Category
# 3 Rating
# 4 Reviews
# 5 Size
# 6 Installs
# 7 Type
# 8 Price
# 9 Content Rating
# 10 Genres
# 11 Last Updated
# 12 Current Ver
# 13 Android Ver

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.3+ MB

# %%
df2.nunique()
# Out:
# App               8190
# Category            33
# Rating              39
# Reviews           5990
# Size               413
# Installs            19
# Type                 2
# Price               73
# Content Rating       6
# Genres             115
# Last Updated      1299
# Current Ver       2638
# Android Ver         31
# dtype: int64

# %%
s = 0
for i in df2.columns:
  s += 1
  print(s,i)
# Out:
# 1 App
# 2 Category
# 3 Rating
# 4 Reviews
# 5 Size
# 6 Installs
# 7 Type
# 8 Price
# 9 Content Rating
# 10 Genres
# 11 Last Updated
# 12 Current Ver
# 13 Android Ver

# %%
df2.nunique()
# Out:
# App               8190
# Category            33
# Rating              39
# Reviews           5990
# Size               413
# Installs            19
# Type                 2
# Price               73
# Content Rating       6
# Genres             115
# Last Updated      1299
# Current Ver       2638
# Android Ver         31
# dtype: int64

# %%
s = 0
for i in df2['Content Rating'].unique():
  s += 1
  print(s,i)
# Out:
# 1 Everyone
# 2 Teen
# 3 Everyone 10+
# 4 Mature 17+
# 5 Adults only 18+
# 6 Unrated

# %%
df2['Content Rating'].value_counts().get('Everyone',0)
# Out:
# 7414

# %%
df2['Content Rating'].value_counts().get('Mature 17+',0)
# Out:
# 461

# %%
df2['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df['Type'].value_counts().get('Free')
# Out:
# 8715

# %%
df['Type'].value_counts().get('Paid')
# Out:
# 645

# %%
print(f"There're total {len(df2['Type'])} applications.")
free = 0
for i in df2['Type']:
  if i == 'Free':
    free += 1
print(f"In which, total {free} Free and",end =' ')

paid = 0
for i in df2['Type']:
  if i == 'Paid':
    paid += 1
print(f"and {paid} paid applications.")
# Out:
# There're total 9360 applications.
# In which, total 8715 Free and and 645 paid applications.

# %%
free + paid
# Out:
# 9360

# %%
print(f'{round(free/(free + paid)*100,2)} %')
# Out:
# 93.11 %

# %%
print(f"{round(paid/(free + paid)*100,2)} %")
# Out:
# 6.89 %

# %%
df2['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
l1 = df2['Content Rating'].unique()
print(len(l1),l1)
# Out:
# 6 ['Everyone' 'Teen' 'Everyone 10+' 'Mature 17+' 'Adults only 18+' 'Unrated']

# %% [markdown]
# # Automatic Categorical

# %%
dfac = data.copy().dropna()

# %%
dfac.shape
# Out:
# (9360, 13)

# %%
dfac.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
for i in dfac['Category'].unique():
  print(i)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION

# %%
PHOTOGRAPHY = 0
for i in dfac['Category']:
  if i == 'PHOTOGRAPHY':
    PHOTOGRAPHY += 1
PHOTOGRAPHY
# Out:
# 317

# %%
dfac['Category'].value_counts().get('PHOTOGRAPHY')
# Out:
# 317

# %%
dfac['Category'].value_counts()
# Out:
# FAMILY                 1746
# GAME                   1097
# TOOLS                   733
# PRODUCTIVITY            351
# MEDICAL                 350
# COMMUNICATION           328
# FINANCE                 323
# SPORTS                  319
# PHOTOGRAPHY             317
# LIFESTYLE               314
# PERSONALIZATION         312
# BUSINESS                303
# HEALTH_AND_FITNESS      297
# SOCIAL                  259
# SHOPPING                238
# NEWS_AND_MAGAZINES      233
# TRAVEL_AND_LOCAL        226
# DATING                  195
# BOOKS_AND_REFERENCE     178
# VIDEO_PLAYERS           160
# EDUCATION               155
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     124
# FOOD_AND_DRINK          109
# HOUSE_AND_HOME           76
# WEATHER                  75
# AUTO_AND_VEHICLES        73
# LIBRARIES_AND_DEMO       64
# ART_AND_DESIGN           61
# COMICS                   58
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# ...

# %%
ART_AND_DESIGN = 0
for i in dfac['Category']:
  if i == 'ART_AND_DESIGN':
    ART_AND_DESIGN += 1
ART_AND_DESIGN
# Out:
# 61

# %%
AUTO_AND_VEHICLES = 0
for i in dfac['Category']:
  if i == 'AUTO_AND_VEHICLES':
    AUTO_AND_VEHICLES += 1
AUTO_AND_VEHICLES
# Out:
# 73

# %%
COMICS = 0
for i in dfac['Category']:
  if i == 'COMICS':
    COMICS += 1
COMICS
# Out:
# 58

# %%
tp = {}

for i in dfac['Type'].unique():
  ct = 0
  for j in dfac['Type']:
    if j == i:
      ct += 1
  tp[i] = ct
tp
# Out:
# {'Free': 8715, 'Paid': 645}

# %%
cr = {}

for i in dfac['Content Rating'].unique():
  ct = 0
  for j in dfac['Content Rating']:
    if j == i:
      ct += 1
  cr[i] = ct
cr
# Out:
# {'Everyone': 7414,
#  'Teen': 1084,
#  'Everyone 10+': 397,
#  'Mature 17+': 461,
#  'Adults only 18+': 3,
#  'Unrated': 1}

# %%
c = 0
for i in dfac.columns:
    c += 1
    print(c,i)
# Out:
# 1 App
# 2 Category
# 3 Rating
# 4 Reviews
# 5 Size
# 6 Installs
# 7 Type
# 8 Price
# 9 Content Rating
# 10 Genres
# 11 Last Updated
# 12 Current Ver
# 13 Android Ver

# %%
gr = {}
for i in dfac['Genres'].unique():
    ct = 0
    for j in dfac['Genres']:
        if j == i:
            ct += 1
    gr[i] = ct

gr
# Out:
# {'Art & Design': 55,
#  'Art & Design;Pretend Play': 2,
#  'Art & Design;Creativity': 7,
#  'Auto & Vehicles': 73,
#  'Beauty': 42,
#  'Books & Reference': 178,
#  'Business': 303,
#  'Comics': 57,
#  'Comics;Creativity': 1,
#  'Communication': 328,
#  'Dating': 195,
#  'Education;Education': 50,
#  'Education': 468,
#  'Education;Creativity': 7,
#  'Education;Music & Video': 5,
#  'Education;Action & Adventure': 6,
#  'Education;Pretend Play': 23,
#  'Education;Brain Games': 4,
#  'Entertainment': 533,
#  'Entertainment;Music & Video': 27,
#  'Entertainment;Brain Games': 8,
#  'Entertainment;Creativity': 3,
#  'Events': 45,
#  'Finance': 323,
#  'Food & Drink': 109,
#  'Health & Fitness': 297,
#  'House & Home': 76,
#  'Libraries & Demo': 64,
#  'Lifestyle': 313,
#  'Lifestyle;Pretend Play': 1,
#  'Adventure;Action & Adventure': 13,
#  'Arcade': 207,
#  'Casual': 185,
#  'Card': 45,
#  'Casual;Pretend Play': 31,
#  'Action': 358,
#  'Strategy': 103,
#  'Puzzle': 120,
# ...

# %%
dfac['Genres'].value_counts().get('Entertainment')
# Out:
# 533

# %%
round(dfac['Rating'].describe(),2)
# Out:
# count    9360.00
# mean        4.19
# std         0.52
# min         1.00
# 25%         4.00
# 50%         4.30
# 75%         4.50
# max         5.00
# Name: Rating, dtype: float64

# %%
dfac['Type'].describe()
# Out:
# count     9360
# unique       2
# top       Free
# freq      8715
# Name: Type, dtype: object

# %%
url = 'https://raw.githubusercontent.com/hrcn81/commonplace/1bbd9c766b7b5323f6115a77c2754f9cecdc50a3/pandas/googleplaystore.csv'
dfc = pd.read_csv(url)

# %%
dfc.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # Null Values Handling - Numeric

# %%
import numpy as np
from sklearn.impute import SimpleImputer

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/hrcn81/commonplace/0604022d476ef11257fb7f68eb7aac3be1766d27/Datasets/Data.csv')

# %%
dt = dataset.copy()

# %%
dt
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    9 non-null      object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  9 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
dt.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy = 'mean')

# %%
dt.iloc[:,dt.columns == 'Salary'].values
# Out:
# array([[72000.],
#        [48000.],
#        [54000.],
#        [61000.],
#        [   nan],
#        [58000.],
#        [52000.],
#        [79000.],
#        [83000.],
#        [67000.]])

# %%
imputer.fit(dt.iloc[:,1:3].values)

x = imputer.transform(dt.iloc[:,1:3].values)

# %%
dt.iloc[:,1:3] = x

# %%
dt.iloc[:,1:3] = round(dt.iloc[:,1:3],0)

# %%
dt
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  63778.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  39.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy = 'most_frequent')

# %%
imputer.fit(dt.loc[:,dt.columns.isin(['Country','Purchased'])])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
z = imputer.transform(dt.loc[:,dt.columns.isin(['Country','Purchased'])])

# %%
z
# Out:
# array([['France', 'Yes'],
#        ['Spain', 'Yes'],
#        ['France', 'Yes'],
#        ['Spain', 'No'],
#        ['Germany', 'Yes'],
#        ['France', 'Yes'],
#        ['Spain', 'No'],
#        ['France', 'Yes'],
#        ['Germany', 'No'],
#        ['France', 'Yes']], dtype=object)

# %%
dt.loc[:,dt.columns.isin(['Country','Purchased'])] = z

# %%
dt
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  63778.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  39.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# # Null Values Handling - Categorical

# %%
df = dataset.copy()

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values = np.nan,strategy = 'most_frequent')

imputer.fit(df.loc[:,df.columns.isin(['Country','Purchased'])])

tf = imputer.transform(df.loc[:,df.columns.isin(['Country','Purchased'])])

df.loc[:,df.columns.isin(['Country','Purchased'])] = tf

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer = SimpleImputer(missing_values = np.nan , strategy = 'mean')

imputer.fit(df.iloc[:,1:3])

agsl = imputer.transform(df.iloc[:,1:3])

df.iloc[:,1:3] = agsl

# %%
df['Age'] = round(df['Age'])
df['Salary'] = round(df['Salary'])

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  63778.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  39.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.iloc[:,1:3].round()
# Out:
#     Age   Salary
# 0  44.0  72000.0
# 1  27.0  48000.0
# 2  30.0  54000.0
# 3  38.0  61000.0
# 4  40.0  63778.0
# 5  35.0  58000.0
# 6  39.0  52000.0
# 7  48.0  79000.0
# 8  50.0  83000.0
# 9  37.0  67000.0

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  63778.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  39.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df1 = dataset.copy()

# %%
df1
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df1.isna().sum()
# Out:
# Country      1
# Age          1
# Salary       1
# Purchased    1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values = np.nan,strategy = 'most_frequent')

imputer.fit(df1.values)

df1.iloc[:,:] = imputer.transform(df1.values)

# %%
df1.round()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df1.isna().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %% [markdown]
# # Null Values Handling on GooglePlaystore Dataset

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/hrcn81/commonplace/main/Datasets/googleplaystore.csv')

# %%
df = dataset.copy()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.dropna().shape
# Out:
# (9360, 13)

# %%
9360/10841 * 100
# Out:
# 86.33889862558804

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df['Rating'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10841 entries, 0 to 10840
# Series name: Rating
# Non-Null Count  Dtype
# --------------  -----
# 9367 non-null   float64
# dtypes: float64(1)
# memory usage: 84.8 KB

# %%
df['Rating'].isna().sum()
# Out:
# 1474

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')

imputer.fit(df.iloc[:,df.columns == 'Rating'])

df['Rating'] = imputer.transform(df.iloc[:,df.columns == 'Rating'])

# %%
df['Rating'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df.shape
# Out:
# (10841, 13)

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.shape
# Out:
# (10829, 13)
